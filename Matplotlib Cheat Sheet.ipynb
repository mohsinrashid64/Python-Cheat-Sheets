# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.layouts import gridplot
from sklearn.datasets import load_iris
iris=load_iris()

# %% [markdown]
# ## Simple Plot

# %%
A=np.linspace(0,10,1000)
B=np.sin(A)
plt.plot(A,B,color="green",marker="o")

# %% [markdown]
# ## Scatter Plot

# %%
A=np.linspace(0,10,100)
B=np.sin(A)
plt.scatter(A,B,color="red")

# %% [markdown]
# ## Plotting on the same plot more than once

# %%
A=np.linspace(0,10,1000)
B=np.sin(A)
C=np.cos(A)
plt.plot(A,B,color="green")
plt.scatter(A,C,color="blue")

# %% [markdown]
# ## Complex Plot

# %%
plt.style.use('classic')
A = np.linspace(0,100,1000)
B = np.cumsum(np.random.randn(1000,5),0)
plt.plot(A,B)
plt.legend('ABCDE',ncol=2,loc='upper left')

# %% [markdown]
# ## Above Are Old Plots

# %% [markdown]
# ##############################################################################

# %% [markdown]
# ## Checking Which Styles are Available

# %%
plt.style.available

# %% [markdown]
# ## Basis for All

# %%
plt.style.use('bmh')
fig= plt.figure()
ax =plt.axes()

# %% [markdown]
# ## Simple Plot

# %%
plt.style.use('bmh')
fig= plt.figure()
ax =plt.axes()
X=np.linspace(0,10,1000)

#BOTH DO THE SAME THING
plt.plot(X,np.sin(X))
# ax.plot(X,np.sin(X))

# %% [markdown]
# ## Multiple Plot

# %%
plt.style.use('bmh')
fig= plt.figure()
ax =plt.axes()
X=np.linspace(0,10,1000)

#BOTH DO THE SAME THING
# plt.plot(X,np.sin(X))
# plt.plot(X,np.cos(X))

ax.plot(X,np.sin(X))

# %% [markdown]
# ## Setting Figure Size, Colors and Styles of the Lines

# %%
X=np.linspace(0,10,1000)

fig=plt.figure(figsize=(10,10))
ax=plt.axes()

ax.plot(X,np.sin(X-0),color='blue')
ax.plot(X,np.sin(X-1),color='g')
ax.plot(X,np.sin(X-2),color=(1.0,0.2,0.3))

plt.plot(X,X+0,linestyle='solid')
plt.plot(X,X+1,linestyle='dashed')
plt.plot(X,X+2,linestyle='dashdot')
plt.plot(X,X+3,linestyle='dotted')

# %% [markdown]
# ## Shortcuts For Colors and Styles

# %%
X=np.linspace(0,10,1000)

fig=plt.figure(figsize=(10,10))
ax=plt.axes()

ax.plot(X,np.sin(X-0),linestyle='--') # dashed
ax.plot(X,np.sin(X-1),linestyle='-') # solid
ax.plot(X,np.sin(X-2),linestyle=':') # dotted

plt.plot(X,X+0,'-g') # solid green
plt.plot(X,X+1,'--c') # dashed cyan
plt.plot(X,X+2,'-.k') # dashdot black
plt.plot(X,X+3,':r') # dotted red

# %% [markdown]
# ## Axis Limits

# %%
X=np.linspace(0,10,1000)

fig=plt.figure(figsize=(10,10))
ax=plt.axes()

ax.plot(X,np.sin(X-0),linestyle='--') # dashed
ax.plot(X,np.sin(X-1),linestyle='-') # solid
ax.plot(X,np.sin(X-2),linestyle=':') # dotted

plt.plot(X,X+0,'-g') # solid green
plt.plot(X,X+1,'--c') # dashed cyan
plt.plot(X,X+2,'-.k') # dashdot black
plt.plot(X,X+3,':r') # dotted red

# %% [markdown]
# ## Limits ane Legends

# %%
X=np.linspace(0,10,1000)
Y1=np.sin(X)
Y2=np.cos(X)
Y3=np.cos(X)+0.3
plt.figure(figsize=(4,3),dpi=100)

plt.plot(X,Y1,'--r',linewidth=0.8,label="sin(X)")
plt.plot(X,Y2,':b',label="cos(X)")
plt.plot(X,Y3,'-k',label="cos(X) + 3")


#NOTE:use all of these separate
# plt.xlim(-2,12)
# plt.ylim(-1.5,1.5)
# plt.axis([-2,11,-2,15])
# plt.axis("tight")
plt.axis("equal")

plt.legend(loc='lower left')

# %% [markdown]
# ### Reverse

# %%
X=np.linspace(0,10,1000)
plt.figure(figsize=(4,2),dpi=100)
plt.plot(X,2*X+3,'--k')
plt.xlim(10,0)

# %% [markdown]
# ## Set Function

# %%
plt.style.use('bmh')

X=np.linspace(0,10,1000)
Y1=np.sin(X)
Y2=np.cos(X)
Y3=np.cos(X)+0.3
plt.figure(figsize=(4,3),dpi=100)

ax=plt.axes()
ax.plot(X,Y1,'--r',linewidth=0.8,label="sin(X)")
ax.plot(X,Y2,':b',label="cos(X)")
ax.plot(X,Y3,'-k',label="cos(X) + 3")

ax.set(xlim=(-1,11),ylim=(-4,3),title="Sin-Cos-Curve")
# plt.axis("equal")

plt.legend(loc='lower left')

# %% [markdown]
# ## Markers for Graphs

# %%
markers = ['o','.','x','+','v','<','>','s','d']

plt.style.use('bmh')

X=np.linspace(-np.pi,np.pi)
Y1=np.sin(X)
Y2=np.cos(X)
Y3=np.cos(X)+0.3
plt.figure(figsize=(4,3),dpi=100)

plt.plot(X,Y1,markers[5],color='green',markersize=3,linestyle='-.')

# %% [markdown]
# ## Random Markers

# %%
markers = ['o','.','x','+','v','<','>','s','d']
plt.figure(figsize=(4,3),dpi=100)
for m in markers:
    plt.plot(np.random.rand(5),np.random.rand(5),m,markersize=5)

# %% [markdown]
# ## Scatter Plot

# %%
X=np.random.randn(100)
Y=np.random.randn(100)

colors=np.random.rand(100)
sizes = 150*np.random.rand(100)
plt.scatter(X,Y,c=colors,s=sizes,alpha=0.3,cmap=plt.cm.viridis)
plt.colorbar()

# %% [markdown]
# ### Iris Scatter Plot (not complete 154)

# %%
from sklearn import datasets
iris = datasets.load_iris()
iris.species()
# clrs = np.random.rand(len(iris.species))

# %% [markdown]
# ## Contour Plots

# %%
X,Y = np.meshgrid([-1,1,2],[5,8,9])
print(X)
print(Y)

# %%
plt.figure(figsize=(4,3))
X,Y = np.meshgrid(np.linspace(0,5,50),np.linspace(0,5,40))
Z = 2*X-5*np.sin(Y)+2
# plt.contour(X,Y,Z,20,cmap="RdGy")
# plt.contourf(X,Y,Z,20,cmap="RdGy")
plt.contourf(X,Y,Z,20,cmap=plt.cm.coolwarm)

plt.colorbar()

# %% [markdown]
# ## Histograms

# %%
plt.figure(figsize=(4,3))
D1 = np.random.normal(0,0.7,1000)
D2 = np.random.normal(-5,2,1000)
D3 = np.random.normal(5,3,1000)

plt.hist(D1,alpha=0.5,bins=50,histtype="stepfilled")
plt.hist(D2,alpha=0.5,bins=50,histtype="stepfilled")
plt.hist(D3,alpha=0.5,bins=50,histtype="stepfilled")

# %% [markdown]
# ### Iris (not complete lec 158)

# %% [markdown]
# ## Subplots

# %%
fig,ax=plt.subplots(2,3,figsize=(4,3),sharex='col',sharey='row')

# %% [markdown]
# ### Simple plot

# %%
fig,ax=plt.subplots(2,3,figsize=(4,3),sharex='col',sharey='row')
for i in range(2):
    for j in range(3):
        ax[i,j].plot(np.random.rand(10),np.random.rand(10),'sg')
        ax[i,j].set(xticks=[],yticks=[])

# %% [markdown]
# ### Images

# %%
fig,ax=plt.subplots(2,3,figsize=(4,3),sharex='col',sharey='row')
for i in range(2):
    for j in range(3):
        ax[i,j].imshow(np.random.rand(200,200),plt.cm.viridis)
        ax[i,j].set(xticks=[],yticks=[]) #disable x and y labels

# %% [markdown]
# #### Real Faces

# %%
from sklearn.datasets import fetch_lfw_people
faces = fetch_lfw_people(min_faces_per_person=70)

# %%
plt.imshow(faces.images[3],plt.cm.bone)

# %%
fi,ax = plt.subplots(4,5,figsize=(4,3),sharex='col',sharey='row')
k=0
for i in range(4):
    for j in range(5):
        ax[i,j].imshow(faces.images[k],plt.cm.bone)
        ax[i,j].set(xticks=[],yticks=[]) #disable x and y labels
        k+=1

# %% [markdown]
# ## plt.gridspec

# %% [markdown]
# ## 3D Plots

# %%
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Simple Plot

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
theta=np.linspace(-4*np.pi,4*np.pi,100)
Z= np.linspace(-2,2,100)
r=Z**2+1
X=r*np.sin(theta)
Y=r*np.cos(theta)
ax.plot(X,Y,Z,label='3D curve')
ax.legend()
ax.set_xlabel('X')
ax.set_ylabel('Y')

# %% [markdown]
# ### Scatter Plot

# %%
fig = plt.figure(figsize=(4,3))
ax = fig.gca(projection='3d')
X=np.random.normal(0,2,100)
Y=np.random.normal(2,4,100)
Z=np.random.normal(6,1,100)
ax.scatter(X,Y,Z,c='g',marker='^',alpha=0.7)

X=np.random.normal(0,2,100)
Y=np.random.normal(2,4,100)
Z=np.random.normal(6,1,100)
ax.scatter(X,Y,Z,c='b',marker='s',alpha=0.7)

X=np.random.normal(10,2,100)
Y=np.random.normal(12,4,100)
Z=np.random.normal(16,1,100)
ax.scatter(X,Y,Z,c='r',marker='+',alpha=0.7)

# %% [markdown]
# ### Surface Plots

# %%
from mpl_toolkits.mplot3d import axes3d

# %%
X,Y,Z = axes3d.get_test_data(0.08)
print(X.shape)
print(Y.shape)
print(Z.shape)

# %%
fig = plt.figure(figsize=(4,3))
ax = fig.gca(projection='3d')
ax.plot_surface(X,Y,Z,cmap=plt.cm.coolwarm,alpha=1)

# %%
X,Y = np.meshgrid(np.linspace(-2,2,500),np.linspace(-2,2,500))
Z=2*np.sin(X)-4*np.cos(X*Y)+3

# %%
fig = plt.figure(figsize=(4,3))
ax = fig.gca(projection='3d')
ax.plot_surface(X,Y,Z,cmap=plt.cm.RdGy,alpha=1)

# %% [markdown]
# ## Gridspec

# %%
https://matplotlib.org/stable/api/_as_gen/matplotlib.gridspec.GridSpec.html

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec


def format_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5, 0.5, "ax%d" % (i+1), va="center", ha="center")
        ax.tick_params(labelbottom=False, labelleft=False)

fig = plt.figure(layout="constrained")

gs = GridSpec(3, 3, figure=fig)
ax1 = fig.add_subplot(gs[0, :])
# identical to ax1 = plt.subplot(gs.new_subplotspec((0, 0), colspan=3))
ax2 = fig.add_subplot(gs[1, :-1])
ax3 = fig.add_subplot(gs[1:, -1])
ax4 = fig.add_subplot(gs[-1, 0])
ax5 = fig.add_subplot(gs[-1, -2])

fig.suptitle("GridSpec")
format_axes(fig)

plt.show()

# %% [markdown]
# ## Slider

# %%
from matplotlib.widgets import Slider
A = pd.Series([2,3,4,5],index=['Issue Period','Issued','Denied','Pending'])
data = {
     'Issued':[48599,22815,2141],
     'Denied':[1733,400,323],
     'Pending':[336,1013,2701]
}

# %%
df = pd.Series(data)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Issued  Denied  Pending
# 0   48599    1733      336
# 1   22815     400     1013
# 2    2141     323     2701

# %%
# %matplotlib notebook
periods = [str(_) for _ in df.index]
issued = df['Issued']
denied = df['Denied']
pending = df['Pending']
dataset = [issued,denied,pending]
fig,ax = plt.subplots(figsize=(9,6))
ax.plot(periods,issued)
plt.subplots_adjust(bottom=0.25)
ax_slider = plt.axes([0.1,0.1,0.8,0.05])


def update_line(indx):
    ax.clear()
    ax.plot(periods,dataset[indx])
    ax.set_title(dataset[indx].name)
    plt.draw()
    

slider = Slider(ax_slider, "Category",valmin=0,valmax=2,valinit=0,valstep=1)
slider.on_changed(update_line)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
periods
# Out:
# ['0', '1', '2']
